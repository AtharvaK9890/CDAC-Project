# %% [markdown]
# ## Import packages

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Extract information about Dataframes

# %%
books = pd.read_csv("Books_unclean.csv")
ratings = pd.read_csv("Ratings_unclean.csv")
users = pd.read_csv("Users.csv")
# Out:
# /tmp/ipykernel_95736/2270960730.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv("Books_unclean.csv")

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0786243244  Murder in the Blood (Five Star First Edition M...
# 1  0140056696                         Modern Irish Short Stories
# 2  037397101X                                   Do Not Go Gentle
# 3  0736900462                                  Jesus, Man of Joy
# 4  0385193866  Gay Life: Leisure, Love, and Living for the Co...
#
#         Book-Author Year-Of-Publication                 Publisher  \
# 0      Gene Deweese                2002            Five Star (ME)
# 1       Ben Forkner                1994               Penguin USA
# 2      Mark Stevens                1989         Worldwide Library
# 3  Sherwood E. Wirt                1999  Harvest House Publishers
# 4        ERIC ROFES                1986                 Doubleday
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0786243244.0...
# 1  http://images.amazon.com/images/P/0140056696.0...
# 2  http://images.amazon.com/images/P/037397101X.0...
# 3  http://images.amazon.com/images/P/0736900462.0...
# 4  http://images.amazon.com/images/P/0385193866.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0786243244.0...
# 1  http://images.amazon.com/images/P/0140056696.0...
# 2  http://images.amazon.com/images/P/037397101X.0...
# 3  http://images.amazon.com/images/P/0736900462.0...
# 4  http://images.amazon.com/images/P/0385193866.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0786243244.0...
# 1  http://images.amazon.com/images/P/0140056696.0...
# 2  http://images.amazon.com/images/P/037397101X.0...
# 3  http://images.amazon.com/images/P/0736900462.0...
# 4  http://images.amazon.com/images/P/0385193866.0...

# %%
ratings.head()
# Out:
#     User-ID        ISBN  Book-Rating
# 0   85940.0  2012360432          0.0
# 1  135149.0  0425155943          0.0
# 2  258185.0  0380818035          0.0
# 3  242306.0  3548254772          0.0
# 4  109049.0  0743227107          0.0

# %%
users.head(5)
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %% [markdown]
# ### Shape of Dataframes

# %%
def shape_of_dataset(df, dataset_name="df"):
    
    print(f"{dataset_name} dataset has {df.shape[0]} nrows and {df.shape[1]} ncolumns")
    return df.shape[0], df.shape[1]

# %%
books_r, books_c = shape_of_dataset(books, "Books")
ratings_r, ratings_c = shape_of_dataset(ratings, "Ratings")
users_r, users_c = shape_of_dataset(users, "Users")
# Out:
# Books dataset has 272800 nrows and 8 ncolumns
# Ratings dataset has 1155447 nrows and 3 ncolumns
# Users dataset has 278858 nrows and 3 ncolumns

# %% [markdown]
# ### Null values in Dataframes

# %%
def count_null_values(df, dataset_name):
    
    num_of_total_null_values = sum(df.isnull().sum().values)
    print(f"{dataset_name} dataset has {num_of_total_null_values} null values")
    return num_of_total_null_values

# %%
books_null = count_null_values(books, "Books")
ratings_null = count_null_values(ratings, "Ratings")
users_null = count_null_values(users, "Users")
# Out:
# Books dataset has 4841 null values
# Ratings dataset has 13177 null values
# Users dataset has 110762 null values

# %% [markdown]
# ### Null columns in Dataframes

# %%
def detect_null_columns(df, dataset_name):
    
    col = []
    s = df.isnull().sum()
    for x in range(len(s)):
        if s[x] > 0:
            col.append(s.index[x])
    tot_cols = len(col)
    if tot_cols == 0:
        print(f"{dataset_name} dataset has no null columns")
        print("="*50)
    else:
        print(f"{dataset_name} dataset has {tot_cols} null columns and they are:")
        for x in col:
            print(x, end=',')
        print()
        print("="*50)
    return col, len(col)

# %%
total_books_null_cols, books_null_cols = detect_null_columns(books, "Books")
total_ratings_null_cols, ratings_null_cols = detect_null_columns(ratings, "Ratings")
total_users_null_cols, users_null_cols = detect_null_columns(users, "Users")
# Out:
# Books dataset has 8 null columns and they are:
# ISBN,Book-Title,Book-Author,Year-Of-Publication,Publisher,Image-URL-S,Image-URL-M,Image-URL-L,
# ==================================================
# Ratings dataset has 3 null columns and they are:
# User-ID,ISBN,Book-Rating,
# ==================================================
# Users dataset has 1 null columns and they are:
# Age,
# ==================================================

# %% [markdown]
# ### Detailed Dataframes

# %%
detailed_db = pd.DataFrame({
    'dataset' : [],
    'nrows' : [],
    'ncols' :[],
    'null_amount' : [],
    'names_of_null_cols' : [],
    'num_null_cols' : []
})

# %%
def fill_db_dataset(dataset_name, nrows, ncols, null_amount, name_null_cols, num_null_cols):
    detailed_db.loc[len(detailed_db.index)] = [dataset_name, nrows, ncols, null_amount, ', '.join(name_null_cols), int(num_null_cols)]

# %%
fill_db_dataset('Books', books_r, books_c, books_null, total_books_null_cols, books_null_cols)
fill_db_dataset('Ratings', ratings_r, ratings_c, ratings_null, total_ratings_null_cols, ratings_null_cols)
fill_db_dataset('Users', users_r, users_c, users_null, total_users_null_cols, users_null_cols)

# %%
detailed_db
# Out:
#    dataset    nrows  ncols  null_amount  \
# 0    Books   272800      8         4841
# 1  Ratings  1155447      3        13177
# 2    Users   278858      3       110762
#
#                                   names_of_null_cols  num_null_cols
# 0  ISBN, Book-Title, Book-Author, Year-Of-Publica...              8
# 1                         User-ID, ISBN, Book-Rating              3
# 2                                                Age              1

# %% [markdown]
# ### Information about Dataframes (df.info)

# %%
def print_info_about_ds(df, name_of_the_ds = "df"):
    print(f"Info about the {name_of_the_ds} dataset: ")
    print("_"*50)
    print(df.info())

# %%
print_info_about_ds(books, "Books")
print("//"*40)

print_info_about_ds(ratings, "Ratings")
print("//"*40)

print_info_about_ds(users, "Users")
# Out:
# Info about the Books dataset:
# __________________________________________________
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 272800 entries, 0 to 272799
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271878 non-null  object
#  1   Book-Title           272095 non-null  object
#  2   Book-Author          272062 non-null  object
#  3   Year-Of-Publication  272796 non-null  object
#  4   Publisher            272187 non-null  object
#  5   Image-URL-S          272241 non-null  object
#  6   Image-URL-M          272244 non-null  object
#  7   Image-URL-L          272056 non-null  object
# dtypes: object(8)
# memory usage: 16.7+ MB
# None
# ////////////////////////////////////////////////////////////////////////////////
# Info about the Ratings dataset:
# __________________________________________________
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1155447 entries, 0 to 1155446
# Data columns (total 3 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   User-ID      1151991 non-null  float64
#  1   ISBN         1151393 non-null  object
#  2   Book-Rating  1149780 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 26.4+ MB
# None
# ////////////////////////////////////////////////////////////////////////////////
# Info about the Users dataset:
# __________________________________________________
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278858 entries, 0 to 278857
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   User-ID   278858 non-null  int64
#  1   Location  278858 non-null  object
#  2   Age       168096 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 6.4+ MB
# None

# %% [markdown]
# ### Unique Values

# %%
def print_nunique_vals(df, ds_name = 'df'):
    print(f"number of unique values in each column in the {ds_name} dataset:")
    print("_"*75)
    print(df.nunique())

# %%
print_nunique_vals(books, 'Books')
print("//"*40)

print_nunique_vals(ratings, 'Ratings')
print("//"*40)

print_nunique_vals(users, 'Users')
# Out:
# number of unique values in each column in the Books dataset:
# ___________________________________________________________________________
# ISBN                   271363
# Book-Title             242136
# Book-Author            102023
# Year-Of-Publication       248
# Publisher               16807
# Image-URL-S            271047
# Image-URL-M            271047
# Image-URL-L            271044
# dtype: int64
# ////////////////////////////////////////////////////////////////////////////////
# number of unique values in each column in the Ratings dataset:
# ___________________________________________________________________________
# User-ID        105283
# ISBN           340558
# Book-Rating        11
# dtype: int64
# ////////////////////////////////////////////////////////////////////////////////
# number of unique values in each column in the Users dataset:
# ___________________________________________________________________________
# User-ID     278858
# Location     57339
# Age            165
# dtype: int64

# %% [markdown]
# ### Plotting missing/null vaues in Dataframes

# %%
import matplotlib.pyplot as plt
import missingno as msno
def plot_miss_vals(df, ds_name):
    msno.matrix(df)
    plt.title(f'Distribution of Missing Values in {ds_name} dataset', fontsize=30, fontstyle='oblique', color='Green')
    plt.show()

# %%
plot_miss_vals(books, "Books")
plot_miss_vals(ratings, "Ratings")
plot_miss_vals(users, "Users")

# %% [markdown]
# ### Data cleaning - removing null values

# %%
books.dropna(inplace=True)
ratings.dropna(inplace=True)

# %% [markdown]
# #### As users age is not relevant for our model so we can drop the column

# %%
users.drop(['Age'],axis=1,inplace=True)

# %%
books.to_csv('Books_final.csv',index=False)
ratings.to_csv('Ratings_final.csv',index=False)
users.to_csv('Users_final.csv',index=False)

# %%
books_final = pd.read_csv('Books_final.csv')
ratings_final = pd.read_csv('Ratings_final.csv')
users_final = pd.read_csv('Users_final.csv')

# %%
books_f_r, books_f_c= shape_of_dataset(books_final, "Books_final")
ratings_f_r, ratings_f_c = shape_of_dataset(ratings_final, "Ratings_final")
users_f_r, users_f_c = shape_of_dataset(users_final, "Users_final")
# Out:
# Books_final dataset has 271354 nrows and 8 ncolumns
# Ratings_final dataset has 1149780 nrows and 3 ncolumns
# Users_final dataset has 278858 nrows and 2 ncolumns

# %% [markdown]
# ### Null values after cleaning

# %%
final_total_books_null_cols, final_books_null_cols = detect_null_columns(books, "Books_final")
final_total_ratings_null_cols, final_ratings_null_cols = detect_null_columns(ratings, "Ratings_final")
final_total_users_null_cols, final_users_null_cols = detect_null_columns(users, "Users_final")
# Out:
# Books_final dataset has no null columns
# ==================================================
# Ratings_final dataset has no null columns
# ==================================================
# Users_final dataset has no null columns
# ==================================================
